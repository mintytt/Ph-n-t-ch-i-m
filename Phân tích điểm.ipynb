# %%
import pandas as pd
pd.set_option('display.max_rows', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df1= pd.read_excel(r'C:\Users\VCB\Documents\Diem\Merge63.xlsx')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 773 entries, 0 to 772
# Data columns (total 33 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   MSSV                                773 non-null    int64
#  1   Tên trường lớp 12_x                 773 non-null    object
#  2   TO                                  773 non-null    float64
#  3   VA                                  759 non-null    float64
#  4   LI                                  757 non-null    float64
#  5   HO                                  758 non-null    float64
#  6   SI                                  754 non-null    float64
#  7   Kỳ 1 lớp 10 môn 1 tổ hợp xét tuyển  773 non-null    float64
#  8   Kỳ 2 lớp 10 môn 1 tổ hợp xét tuyển  773 non-null    float64
#  9   Kỳ 1 lớp 11 môn 1 tổ hợp xét tuyển  773 non-null    float64
#  10  Kỳ 2 lớp 11 môn 1 tổ hợp xét tuyển  773 non-null    float64
# ...

# %%
# Visulazing the distibution of the data for every feature
df1.hist(edgecolor='black', linewidth=1.2, figsize=(20, 20));

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df1.corr(), annot=True)

# %%
df1.drop(['MSSV'],axis=1).describe()
# Out:
#                TO          VA          LI          HO          SI  \
# count  773.000000  759.000000  757.000000  758.000000  754.000000
# mean     7.606727    5.561805    7.440225    6.730541    4.834881
# std      0.745387    1.230177    1.273124    1.730487    1.367641
# min      4.000000    2.500000    1.750000    1.750000    1.500000
# 25%      7.200000    4.750000    7.000000    5.750000    3.750000
# 50%      7.600000    5.750000    7.750000    7.250000    4.750000
# 75%      8.200000    6.500000    8.250000    8.000000    5.750000
# max      9.600000    9.000000   10.000000   10.000000    8.500000
#
#        Kỳ 1 lớp 10 môn 1 tổ hợp xét tuyển  Kỳ 2 lớp 10 môn 1 tổ hợp xét tuyển  \
# count                          773.000000                          773.000000
# mean                             8.577102                            8.702367
# std                              0.745735                            0.705523
# ...

# %%
df1["Tên trường lớp 12_y"].value_counts().plot(kind='bar',figsize=(20,20))

# %%
df2= pd.read_excel(r'C:\Users\VCB\Documents\Diem\Merge64.xlsx')

# %%
# Visulazing the distibution of the data for every feature
df2.hist(edgecolor='black', linewidth=1.2, figsize=(20, 20));

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(df2.corr(), annot=True)

# %%
df2.drop(['MSSV'],axis=1).describe()
# Out:
#            Đ.Toán       Đ.Văn        Đ.Lý       Đ.Hóa      Đ.Sinh  \
# count  522.000000  514.000000  518.000000  515.000000  511.000000
# mean     8.676245    5.766693    7.714768    6.890291    4.892368
# std      0.606626    1.027244    1.309498    1.680557    1.269711
# min      6.000000    2.250000    1.750000    1.500000    1.750000
# 25%      8.400000    5.250000    7.250000    5.875000    4.000000
# 50%      8.800000    5.750000    8.000000    7.500000    4.750000
# 75%      9.200000    6.500000    8.500000    8.000000    5.500000
# max      9.800000    8.500000    9.750000    9.500000    9.500000
#
#        Kỳ 1 lớp 10 môn 1 tổ hợp xét tuyển  Kỳ 2 lớp 10 môn 1 tổ hợp xét tuyển  \
# count                          523.000000                          523.000000
# mean                             8.631147                            8.702868
# std                              0.684070                            0.629458
# ...

# %%
df2["Tên trường lớp 12"].value_counts().plot(kind='bar',figsize=(20,20))
